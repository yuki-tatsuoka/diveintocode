# %% [markdown]
# # 【問題1】データセットの取得
# pd.read_csv()を使用して、変数に格納してください。

# %%
import pandas as pd

df = pd.read_csv("/Users/yuki.tatsuoka/Downloads/house-prices-advanced-regression-techniques (1)/train.csv")
df
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
# ...

# %% [markdown]
# # 【問題2】データセット自体の調査
# KaggleのOverviewページや、Dataページの「Data fields」などを読みながら、どのようなデータセットかを説明してください。

# %%
"""
考察
概要は、住宅データの説明変数から実際の値と予測の値を近づけるためのデータセット。
評価指標はRMSEを使って誤差の最小化を求める課題
データの中身については、道路のアクセス状況や、建物のクラス、住宅のスタイルなど様々ある。
抽象化すると家の素材や家の大きさなど家に関する説明変数、交通アクセスの利便性など物価を決定するまでの条件が記載されている。
その数は81種類、データ量は欠損値を含めて1460ほどある。
"""
# Out:
# '\n考察\n概要は、住宅データの説明変数から実際の値と予測の値を近づけるためのデータセット。\n評価指標はRMSEを使って誤差の最小化を求める課題\nデータの中身については、道路のアクセス状況や、建物のクラス、住宅のスタイルなど様々ある。\n抽象化すると家の素材や家の大きさなど家に関する説明変数、交通アクセスの利便性など物価を決定するまでの条件が記載されている。\nその数は81種類、データ量は欠損値を含めて1460ほどある。\n'

# %% [markdown]
# # 【問題3】データの確認
# データを確認していきます。コードとマークダウンを組み合わせてレポートしてください。
#
#
# 1. 各特徴量がどういったものかを見る。（数値データか文字データなど）
# 2. 今回の目的変数はどの列か確認する。
# 3. 特徴量の平均値と標準偏差、四分位数を一度に表示させる。

# %% [markdown]
# #### 1. 各特徴量がどういったものかを見る。（数値データか文字データなど）

# %%
# データの型を確認する 
df.info()

'''
int,float,object型に別れており、object型が多く存在する
また、欠損値も多く含まれている。

'''
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   object
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   object
#  6   Alley          91 non-null     object
#  7   LotShape       1460 non-null   object
#  8   LandContour    1460 non-null   object
#  9   Utilities      1460 non-null   object
#  10  LotConfig      1460 non-null   object
#  11  LandSlope      1460 non-null   object
#  12  Neighborhood   1460 non-null   object
#  13  Condition1     1460 non-null   object
#  14  Condition2     1460 non-null   object
#  15  BldgType       1460 non-null   object
#  16  HouseStyle     1460 non-null   object
# ...

# %% [markdown]
# #### 2. 今回の目的変数はどの列か確認する。
#  df["SalePrice"]が目的変数

# %%
# データを確認する
df.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# ...

# %% [markdown]
# ##### 3. 特徴量の平均値と標準偏差、四分位数を一度に表示させる。

# %%
df.describe()
# Out:
#                 Id   MSSubClass  LotFrontage        LotArea  OverallQual  \
# count  1460.000000  1460.000000  1201.000000    1460.000000  1460.000000
# mean    730.500000    56.897260    70.049958   10516.828082     6.099315
# std     421.610009    42.300571    24.284752    9981.264932     1.382997
# min       1.000000    20.000000    21.000000    1300.000000     1.000000
# 25%     365.750000    20.000000    59.000000    7553.500000     5.000000
# 50%     730.500000    50.000000    69.000000    9478.500000     6.000000
# 75%    1095.250000    70.000000    80.000000   11601.500000     7.000000
# max    1460.000000   190.000000   313.000000  215245.000000    10.000000
#
#        OverallCond    YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1  ...  \
# count  1460.000000  1460.000000   1460.000000  1452.000000  1460.000000  ...
# mean      5.575342  1971.267808   1984.865753   103.685262   443.639726  ...
# std       1.112799    30.202904     20.645407   181.066207   456.098091  ...
# ...

# %% [markdown]
# #  【問題4】欠損値への対応
# 欠損値に関して以下のことを行い、レポートしてください。
#
#
# 各特徴量の欠損値の有無を確認する。
#
# 欠損値の確認にはmissingnoというライブラリを活用しましょう。このライブラリにより欠損値の有無が可視化できます。インストールや使い方に関しては以下のページをご覧ください。
#
#
# ResidentMario/missingno: Missing data visualization module for Python.
#
#
# 欠損値が何パーセント含まれるかを確認する。
#
# 1. 5つ以上欠損値がある特徴量（列）は削除する。
# 2. 欠損値があるサンプル（行）は削除する。

# %%
# missingnoを使って%の把握と可視化する
import missingno as msno

#可視化
msno.bar(df)

# %%
# 欠損値の有無の確認
nan_list = df.isnull().sum()
nan_list
# Out:
# Id                 0
# MSSubClass         0
# MSZoning           0
# LotFrontage      259
# LotArea            0
#                 ...
# MoSold             0
# YrSold             0
# SaleType           0
# SaleCondition      0
# SalePrice          0
# Length: 81, dtype: int64

# %%
# 欠損値のあるものだけ所得する
nan_list = nan_list[nan_list > 0]
print("欠損値の数は{}".format(len(nan_list)))
print(nan_list)

# 5以上の欠損値があるものは列を削除する
Electrical = df["Electrical"] #欠損値が１つなので残す
df = df.drop(df[nan_list.index], axis=1)
pd.concat([df,Electrical], axis=1)
# Out:
# 欠損値の数は19
# LotFrontage      259
# Alley           1369
# MasVnrType         8
# MasVnrArea         8
# BsmtQual          37
# BsmtCond          37
# BsmtExposure      38
# BsmtFinType1      37
# BsmtFinType2      38
# Electrical         1
# FireplaceQu      690
# GarageType        81
# GarageYrBlt       81
# GarageFinish      81
# GarageQual        81
# GarageCond        81
# PoolQC          1453
# Fence           1179
# MiscFeature     1406
# dtype: int64
#         Id  MSSubClass MSZoning  LotArea Street LotShape LandContour  \
# 0        1          60       RL     8450   Pave      Reg         Lvl
# 1        2          20       RL     9600   Pave      Reg         Lvl
# 2        3          60       RL    11250   Pave      IR1         Lvl
# 3        4          70       RL     9550   Pave      IR1         Lvl
# 4        5          60       RL    14260   Pave      IR1         Lvl
# ...    ...         ...      ...      ...    ...      ...         ...
# ...

# %%
# 欠損値があるサンプル（行）は削除する。
df.dropna(how="any",axis=0, inplace=True)

#欠損値の確認
df.isnull().sum().sum()
# Out:
# 0

# %% [markdown]
# # 【問題5】用語の調査
# 以下の２つの単語を知る必要があります。これらを調査してまとめてください。
#
#
# 尖度</br>
# 歪度

# %%
'''
尖度：
分布図にした際にどれだけ中央でデータが縦に集まっているか示す指標。
＋なら中央に凸してデータが集まり、-なら平面のような形をする。
0なら正規分布に従う

歪度：
分布図にした際に中央からどれだけ左右にずれているか示す指標。
+なら左に伸びており（左裾が長い）、ーなら右にずれている（右裾が長い）。
0なら正規分布に従う
'''

# %% [markdown]
# # 【問題6】分布の確認
# seabornのsns.distplot()を使い目的変数の分布を表示し、「尖度」と「歪度」も算出する。
# 目的変数に対して対数変換を行う。
# 対数変換したものに対して分布を表示し、「尖度」と「歪度」も算出する。
#
# 対数変換の前後での変化を「正規分布」という言葉を含めて説明してください。このように加工することで予測時の精度を上げることができます。

# %%
import numpy as np
from scipy.stats import skew
from scipy.stats import kurtosis

# 目的変数の抽出
SalePrice = df["SalePrice"]

# 歪度と尖度を抽出する
objective_skew1 = skew(SalePrice)
objective_kurtosis1 = kurtosis(SalePrice)
print("尖度{}, 歪度{}".format(objective_skew1, objective_kurtosis1))

#図式化
sns.distplot(SalePrice)
plt.show()

# 対数変換
log_SalePrice = np.log(SalePrice)

# 歪度と尖度を抽出する
objective_skew2 = skew(log_SalePrice)
objective_kurtosis2 = kurtosis(log_SalePrice)
print("尖度{}, 歪度{}".format(objective_skew2, objective_kurtosis2))

# 図式化
sns.distplot(log_SalePrice)
plt.show()

'''
考察
結論から言うと、尖度、歪度共に改善され０付近の値に戻りほとんど正規分布に従う分布になっている。
元のデータでは、正規分布から離れているため正規分布に従うように対数変換を実施する方が好ましい。

また、対数変換は弾力性を見ており、〇〇％増加などの値を見ている。
対数変換を実施しない場合は、通常xの増加量1に対し、yが40増加など実数で見ている。

logの対数はグラフで見ると、0になるまでに急激に増加し〇〇％増加などのサンプル数が大きくなる事により誤差が小さくなる傾向がある。
基本的に歪度があれば対数変換をし、グラフで確認する事が好ましいがyが0以下ならば基本的には誤差が小さくなるので実施した方が良い。
（あとはデータの散らばりも減るので、過学習を抑制しやすいと考えられる）
'''
# Out:
# 尖度1.880940746034036, 歪度6.509812011089439
# 尖度0.1212103673013655, 歪度0.8026555069117713
# '\n考察\n結論から言うと、尖度、歪度共に改善され０付近の値に戻りほとんど正規分布に従う分布になっている。\n元のデータでは、正規分布から離れているため正規分布に従うように対数変換を実施する方が好ましい。\n\nまた、対数変換は弾力性を見ており、〇〇％増加などの値を見ている。\n対数変換を実施しない場合は、通常xの増加量1に対し、yが40増加など実数で見ている。\n\nlogの対数はグラフで見ると、0になるまでに急激に増加し〇〇％増加などのサンプル数が大きくなる事により誤差が小さくなる傾向がある。\n基本的に歪度があれば対数変換をし、グラフで確認する事が好ましいがyが0以下ならば基本的には誤差が小さくなるので実施した方が良い。\n（あとはデータの散らばりも減るので、過学習を抑制しやすいと考えられる）\n'

# %% [markdown]
# # 【問題7】相関係数の確認
# 特徴量の確認をしていきます。それぞれに対してマークダウンで説明や考察を書いてください。
#
#
# 相関係数行列のヒートマップを作り、相関係数の高い関係を見つける。
# 目的変数との相関の高い特徴量10個を選び、これらだけの相関係数行列ヒートマップを作る。
# 選んだ10個の特徴量が何か表しているかをKaggleのDataDescriptionの記述を参考に日本語でまとめる。
# 選んだ10個の特徴量の中でお互いの相関係数が高い組み合わせを3つ探し出す。
#
# 《補足》
#
#
# 重回帰分析などで予測する場合、相関が高すぎる特徴量の組み合わせがあると予測に悪影響が出ることがあります。このような場合の簡単な対処方法として、そういった特徴量の組みを探し出して、１つに絞るということがあります。

# %%
# 相関係数行列のヒートマップを作り、相関係数の高い関係を見つける
plt.figure(figsize=(10,10))
correlation_coefficient = df.corr()
sns.heatmap(correlation_coefficient,
                    vmin=-1.0,
                    vmax=1.0,
                    center=0.0,
                    annot=False)
plt.show()
'''
LotAreaとSalePrice、
SalePriceとOverallaCond、
KitchenAbvGr、GrLivAreaの相関は強い
'''
#  目的変数との相関の高い特徴量10個を選び、これらだけの相関係数行列ヒートマップを作る。
df2 = pd.concat([df["OverallCond"],df["TotalBsmtSF"],df["2ndFlrSF"],df["HalfBath"],df["GrLivArea"],df["Fireplaces"],df["YearRemodAdd"],df["BsmtFinSF2"],df["OpenPorchSF"],df["3SsnPorch"]], axis=1)

correlation_coefficient2 = df2.corr()
sns.heatmap(correlation_coefficient2,
                    vmin=-1.0,
                    vmax=1.0,
                    center=0.0,
                    annot=False)
plt.show()
#  選んだ10個の特徴量が何か表しているかをKaggleのDataDescriptionの記述を参考に日本語でまとめる
'''
10種類の特徴量説明
OverallCond：総合状態評価
TotalBsmtSF：地下室の総平方フィート
2ndFlrSF：2階平方フィート
HalfBath：グレード以上のハーフバス
GrLivArea：地上（地上）のリビングエリアの平方フィート
Fireplaces：暖炉の数
YearRemodAdd：改造日
BsmtFinSF2：タイプ2の完成した平方フィート
OpenPorchSF：平方フィート単位のオープンポーチエリア
3SsnPorch：平方フィートの3シーズンポーチエリア
'''

# 選んだ10個の特徴量の中でお互いの相関係数が高い組み合わせを3つ探し出す。
'''
2ndFlrSFとGrLivArea
2ndFlrSFとHalfBath
GrLivAreaとTotalBsmtSFの相関が強い
'''
# Out:
# '\n2ndFlrSFとGrLivArea\n2ndFlrSFとHalfBath\nGrLivAreaとTotalBsmtSFの相関が強い\n'
